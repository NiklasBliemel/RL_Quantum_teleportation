# %%
from labfuncs import *

# %%
test("mlp_1_(512_0.0003_0.0)")
# Out:
# {'Step': 0, 'M': 0, 'Action': 'M->[2]', 'Terminal': False}
# {'Step': 1, 'M': None, 'Action': 'H->[0]', 'Terminal': False}
# {'Step': 2, 'M': None, 'Action': 'CX->[0, 1]', 'Terminal': False}
# {'Step': 3, 'M': None, 'Action': 'CX->[2, 1]', 'Terminal': False}
# {'Step': 4, 'M': None, 'Action': 'X->[2]', 'Terminal': False}
# {'Step': 5, 'M': 0, 'Action': 'M->[0]', 'Terminal': False}
# {'Step': 6, 'M': None, 'Action': 'X->[2]', 'Terminal': False}
# {'Step': 7, 'M': None, 'Action': 'Z->[0]', 'Terminal': False}
# {'Step': 8, 'M': None, 'Action': 'X->[2]', 'Terminal': False}
# {'Step': 9, 'M': None, 'Action': 'Z->[1]', 'Terminal': False}
# {'Step': 10, 'M': None, 'Action': 'Z->[1]', 'Terminal': False}
# {'Step': 11, 'M': None, 'Action': 'Step limit reached', 'Terminal': True}
# Failure!

# %%
for name in os.listdir("logs"):
    print(name)
    last_timestep(name)
    print()
# Out:
# mlp_3_(256_0.0003_0.0).npz
# 1.00e+06
#
# mlp_0_(512_0.0003_0.0).npz
# 9.98e+05
#
# mlp_1_(512_0.0003_0.0).npz
# 7.51e+05
#
# mlp_2_(256_0.0003_0.0).npz
# 9.97e+05
#
# mlp_1_(256_0.0003_0.0).npz
# 9.99e+05
#
# mlp_4_(256_0.0003_0.0).npz
# 9.99e+05
#
# mlp_0_(256_0.0003_0.0).npz
# 1.00e+06

# %%
for name in os.listdir("logs"):
    print(name)
    best_val(name)
    print()
# Out:
# mlp_3_(256_0.0003_0.0).npz
# -16.0
#
# mlp_0_(512_0.0003_0.0).npz
# -16.0
#
# mlp_1_(512_0.0003_0.0).npz
# -16.0
#
# mlp_2_(256_0.0003_0.0).npz
# -16.0
#
# mlp_1_(256_0.0003_0.0).npz
# -16.0
#
# mlp_4_(256_0.0003_0.0).npz
# -16.0
#
# mlp_0_(256_0.0003_0.0).npz
# -16.0
